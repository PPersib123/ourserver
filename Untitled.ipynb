# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
cap = cv2.VideoCapture('metamorph.webm')
print(cap)
# Out:
# <VideoCapture 0x7f2dea1a2ed0>

# %%
img  = cap.read()[1]
img.shape
plt.imshow(img[:,:,0])
